# %%
# Import the library
from hgboost import hgboost

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

from skopt import BayesSearchCV
from xgboost import XGBRegressor
from sklearn.model_selection import train_test_split

# %%
# Preparing the data

df = pd.read_csv('df_train.csv')
df.drop('Unnamed: 0', axis=1, inplace=True)
# reading test data
df_test = pd.read_csv('df_test.csv')
df_test.drop('Unnamed: 0', axis=1, inplace=True)

df
# Out:
#       N     xm    nr     ni         p1        p2        p3
# 0     7  0.640  1.71  0.045   1.685110 -0.001577 -0.009044
# 1    10  0.336  1.30  0.023   2.235463 -0.096444 -0.104801
# 2     6  0.640  1.30  0.023   0.339716 -0.000123 -0.002486
# 3     7  0.480  1.30  0.023   0.618308 -0.000189 -0.001309
# 4     8  0.530  1.80  0.023   1.429310 -0.007968 -0.013564
# ..   ..    ...   ...    ...        ...       ...       ...
# 210   9  0.479  1.45  0.023   3.861650 -0.113987 -0.158734
# 211   8  0.960  1.30  0.023   6.662236 -0.206193 -0.104666
# 212   8  0.960  2.00  0.090  14.004366 -0.546805 -0.380360
# 213   7  0.440  1.66  0.086   0.860949 -0.000236 -0.001893
# 214   8  0.640  1.68  0.004   2.406016 -0.037758 -0.049270
#
# [215 rows x 7 columns]

# %%
from bhmie import *

data = pd.read_csv('allregimes.csv')

def calc_tau(N, xm, nr, ni):
    N = 2**N
    s1,s2,qext,qsca,qback,gsca = bhmie(xm,complex(nr, ni),91)
    csca_mon = qsca * np.pi * xm**2
    cext_mon = qext * np.pi * xm**2
    cabs_mon = (qext - qsca) * np.pi * xm**2

    R1 = 1.598
    Rcut = 1. / 0.0001
    Df = 2.0
    Rmin=2.0
    #dstep = 1/(8*xm)
    ds = 1/(8*xm)
    Rmax = R1*(N*np.log(Rcut))**(1.0/Df)
    nstep = int((Rmax - Rmin) /ds)
    nstep = np.where(nstep < 100, 100, nstep)
    dstep = (Rmax - Rmin)/(nstep-1)

    R0 = np.arange(nstep)*dstep + Rmin
    dist = R0 * xm
    nc = ((1.0 - np.exp(-(R0/R1)**(Df) /N))*(1.0 - np.exp(-(R0/3.478)**3.194)) + (2.0/N) )/(1 + (2.0/N))
    #nc=1.0 - np.exp(-(R0/R1)**(Df) /N)
    f0 = np.zeros(nstep)
    f0[0] = 0.5 * (nc[1]-nc[0]) + nc[0] # this seems to include nc[0] erronously
    #f0[0] = 0.5 * (nc[1]-nc[0])
    f0[nstep-1] =  1. - nc[nstep-1] + 0.5 * (nc[nstep-1]-nc[nstep-2])
    #f0[nstep-1] = 0.5 * (nc[nstep-1]-nc[nstep-2]) #
    f0[1:(nstep-1)] =  (nc[2:(nstep)] - nc[0:(nstep-2)])/(2)
    tau_coef = np.sum(f0 / dist**2) / 4. / np.pi * (N-1)
    taue_out = tau_coef * cext_mon
    taus_out = tau_coef * csca_mon
    taua_out = tau_coef * cabs_mon
    return taus_out, taua_out

# %%
tau_new = df_test.apply(lambda row: pd.Series(calc_tau(row['N'], row['xm'], row['nr'], row['ni'])), axis=1).values
taus_out = tau_new[:,0]
taua_out = tau_new[:,1]
df_test[['taus_out', 'taua_out']] = tau_new
df_test['taue_out'] = df_test['taua_out'] + df_test['taus_out']
df_test.head()
# Out:
#    N     xm    nr     ni        p1        p2        p3  taus_out  taua_out  \
# 0  8  0.580  1.30  0.023  1.264126 -0.010829 -0.011088  0.005848  0.019430
# 1  8  0.640  1.30  0.004  1.862944 -0.032417 -0.037803  0.008537  0.003804
# 2  8  0.530  1.68  0.023  1.381302 -0.007667 -0.012352  0.018159  0.014732
# 3  8  0.640  1.30  0.023  1.738920 -0.019180 -0.017325  0.008554  0.021798
# 4  8  0.336  1.30  0.004  0.396932 -0.000567 -0.001742  0.000679  0.001849
#
#    taue_out
# 0  0.025278
# 1  0.012342
# 2  0.032892
# 3  0.030352
# 4  0.002529

# %%
tau_new = df.apply(lambda row: pd.Series(calc_tau(row['N'], row['xm'], row['nr'], row['ni'])), axis=1).values
taus_out = tau_new[:,0]
taua_out = tau_new[:,1]
df[['taus_out', 'taua_out']] = tau_new
df['taue_out'] = df['taua_out'] + df['taus_out']
df.head()
# Out:
#     N     xm    nr     ni        p1        p2        p3  taus_out  taua_out  \
# 0   7  0.640  1.71  0.045  1.685110 -0.001577 -0.009044  0.036756  0.032244
# 1  10  0.336  1.30  0.023  2.235463 -0.096444 -0.104801  0.000848  0.013196
# 2   6  0.640  1.30  0.023  0.339716 -0.000123 -0.002486  0.006375  0.016244
# 3   7  0.480  1.30  0.023  0.618308 -0.000189 -0.001309  0.002443  0.013706
# 4   8  0.530  1.80  0.023  1.429310 -0.007968 -0.013564  0.023747  0.013823
#
#    taue_out
# 0  0.069000
# 1  0.014044
# 2  0.022619
# 3  0.016149
# 4  0.037570

# %%
_ = sns.set_palette('colorblind')
_ = sns.heatmap(df.corr(),  cmap='gist_heat_r')
plt.show()

# %% [markdown]
# __Let's convert the optical terms to the exponential terms which is physically relavant and may provide more linear relationship between phase function.__
#
# $exp(-\tau _abs)$ and $exp(\tau _sca)$

# %%
df['taua_out'] = -1*np.exp(df['taua_out'])
df['taus_out'] = np.exp(df['taus_out'])

df_test['taua_out'] = -1*np.exp(df_test['taua_out'])
df_test['taus_out'] = np.exp(df_test['taus_out'])

# %% [markdown]
# #### Modelling Strategy
# For each observation there are three response variables. The response variables, p1, p2, p3 are ceofficients of a legendre polynomial describing the same curve of a phase function that corresponds to an aerosol particle with features N, xm, nr, ni. Therefore each response variable depend on the features as well as each other. Finally the relationship between the the features and response variable may not be linear.
#
# Based on these properties of the data using a tree based algorithm I will first model p1 using the features in the data

# %% [markdown]
# # Step 1 Modelling P1

# %%
# For p1 do not use any p columns as predictor
X = df.drop(columns=['p1', 'p2', 'p3'])
y1 = df['p1'].values

X_test = df_test.drop(columns=['p1', 'p2', 'p3'])
y_test1 = df_test['p1']

# %%
# Define the search space for hyperparameters
params = {
    'learning_rate': (0.0005, 1.0, 'log-uniform'),
    'n_estimators': (10, 5000),
    'max_depth': (1, 50),
    'min_child_weight': (1, 10),
    'subsample': (0.1, 1.0, 'uniform'),
    'colsample_bytree': (0.1, 1.0, 'uniform')
}

# Define the XGBoost regression model
xgb = XGBRegressor()

# %%
# Define the BayesSearchCV object for hyperparameter tuning
bayes_cv1 = BayesSearchCV(
    estimator=xgb,
    search_spaces=params,
    cv=4,
    n_iter=250,
    n_jobs=-1,
    verbose=0
)

# Fit the BayesSearchCV object to the training data
bayes_cv1.fit(X, y1)
# Out:
# BayesSearchCV(cv=4,
#               estimator=XGBRegressor(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False, eval_metric=None,
#                                      feature_types=None, gamma=None,
#                                      gpu_id=None, grow_policy=None,
#                                      importance_type=None,
#                                      interaction_constraints=None,
#                                      learning_rate=None,...
#                                      max_leaves=None, min_child_weight=None,
#                                      missing=nan, monotone_constraints=None,
#                                      n_estimators=100, n_jobs=None,
#                                      num_parallel_tree=None, predictor=None,
#                                      random_state=None, ...),
#               n_iter=250, n_jobs=-1,
#               search_spaces={'colsample_bytree': (0.1, 1.0, 'uniform'),
#                              'learning_rate': (0.0005, 1.0, 'log-uniform'),
#                              'max_depth': (1, 50), 'min_child_weight': (1, 10),
#                              'n_estimators': (10, 5000),
#                              'subsample': (0.1, 1.0, 'uniform')})

# %%
# Print the best set of hyperparameters found by the optimization algorithm
print("Best hyperparameters: ", bayes_cv1.best_params_)
# Out:
# Best hyperparameters:  OrderedDict([('colsample_bytree', 0.9309633918846848), ('learning_rate', 0.0056238213226800175), ('max_depth', 30), ('min_child_weight', 2), ('n_estimators', 4298), ('subsample', 0.8460069129192667)])

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Evaluate the performance of the best model on the test set
y_pred = bayes_cv1.predict(X_test)
mae = mean_absolute_error(y_test1, y_pred)
rmse = mean_squared_error(y_test1, y_pred, squared=False)
r2 = r2_score(y_test1, y_pred)

print("Mean Absolute Error: {:.3f}".format(mae))
print("Root Mean Squared Error: {:.3f}".format(rmse))
print("R-squared Score: {:.3f}".format(r2))
# Out:
# Mean Absolute Error: 0.706
# Root Mean Squared Error: 1.644
# R-squared Score: 0.852

# %%
# Save the best model to disk
import joblib
joblib.dump(bayes_cv1.best_estimator_, 'xgb_model_p1_tau_no_aug.joblib')
# Out:
# ['xgb_model_p1_tau_no_aug.joblib']

# %%
y_residual1.shape
# Out:
# (393,)

# %% [markdown]
# ## Second model - P2
# For model P2 we use the standard features and p1 as predictor

# %%
# 
X2 = df.drop(columns=['p2', 'p3'])
X_test2 = df_test.drop(columns=['p2', 'p3'])

y2 = df['p2'].values
y_test2 = df_test['p2']

# %%
# Define the BayesSearchCV object for hyperparameter tuning
bayes_cv2 = BayesSearchCV(
    estimator=xgb,
    search_spaces=params,
    cv=3,
    n_iter=250,
    n_jobs=-1,
    verbose=1
)

# Fit the BayesSearchCV object to the training data
bayes_cv2.fit(X2, y2 )
# Out:
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# BayesSearchCV(cv=3,
#               estimator=XGBRegressor(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False, eval_metric=None,
#                                      feature_types=None, gamma=None,
#                                      gpu_id=None, grow_policy=None,
#                                      importance_type=None,
#                                      interaction_constraints=None,
#                                      learning_rate=None,...
#                                      missing=nan, monotone_constraints=None,
#                                      n_estimators=100, n_jobs=None,
#                                      num_parallel_tree=None, predictor=None,
#                                      random_state=None, ...),
#               n_iter=250, n_jobs=-1,
#               search_spaces={'colsample_bytree': (0.1, 1.0, 'uniform'),
#                              'learning_rate': (0.0005, 1.0, 'log-uniform'),
#                              'max_depth': (1, 50), 'min_child_weight': (1, 10),
#                              'n_estimators': (10, 5000),
#                              'subsample': (0.1, 1.0, 'uniform')},
#               verbose=1)

# %%
# Print the best set of hyperparameters found by the optimization algorithm
print("Best hyperparameters: ", bayes_cv2.best_params_)
# Out:
# Best hyperparameters:  OrderedDict([('colsample_bytree', 0.7115304242215906), ('learning_rate', 0.023241566362602096), ('max_depth', 45), ('min_child_weight', 3), ('n_estimators', 3045), ('subsample', 0.9930863164982008)])

# %%
joblib.dump(bayes_cv1.best_estimator_, 'xgb_model_p2_tau_no_aug.joblib')
# Out:
# ['xgb_model_p2_tau_no_aug.joblib']

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Evaluate the performance of the best model on the test set
y_pred2 = bayes_cv2.predict(X_test2)
mae = mean_absolute_error(y_test2, y_pred2)
rmse = mean_squared_error(y_test2, y_pred2, squared=False)
r2 = r2_score(y_test2, y_pred2)

print("Mean Absolute Error: {:.3f}".format(mae))
print("Root Mean Squared Error: {:.3f}".format(rmse))
print("R-squared Score: {:.3f}".format(r2))
# Out:
# Mean Absolute Error: 0.108
# Root Mean Squared Error: 0.241
# R-squared Score: 0.791

# %% [markdown]
# # Third Model - P3
# For P3 we use standard features plus P1 and P2 as predictors

# %%
# Dropping only P3 leaves p1 and p2 among the predictors
X3 = df.drop(columns=['p3'])
X_test3 = df_test.drop(columns=['p3'])

y3 = df['p3'].values
y_test3 = df_test['p3']

# Define the BayesSearchCV object for hyperparameter tuning
bayes_cv3 = BayesSearchCV(
    estimator=xgb,
    search_spaces=params,
    cv=3,
    n_iter=250,
    n_jobs=-1,
    verbose=0
)

# Fit the BayesSearchCV object to the training data
bayes_cv3.fit(X3, y3 )
# Out:
# BayesSearchCV(cv=3,
#               estimator=XGBRegressor(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False, eval_metric=None,
#                                      feature_types=None, gamma=None,
#                                      gpu_id=None, grow_policy=None,
#                                      importance_type=None,
#                                      interaction_constraints=None,
#                                      learning_rate=None,...
#                                      max_leaves=None, min_child_weight=None,
#                                      missing=nan, monotone_constraints=None,
#                                      n_estimators=100, n_jobs=None,
#                                      num_parallel_tree=None, predictor=None,
#                                      random_state=None, ...),
#               n_iter=250, n_jobs=-1,
#               search_spaces={'colsample_bytree': (0.1, 1.0, 'uniform'),
#                              'learning_rate': (0.0005, 1.0, 'log-uniform'),
#                              'max_depth': (1, 50), 'min_child_weight': (1, 10),
#                              'n_estimators': (10, 5000),
#                              'subsample': (0.1, 1.0, 'uniform')})

# %%
# Print the best set of hyperparameters found by the optimization algorithm
print("Best hyperparameters: ", bayes_cv3.best_params_)
# Out:
# Best hyperparameters:  OrderedDict([('colsample_bytree', 0.7021935383947884), ('learning_rate', 0.009159112014396805), ('max_depth', 29), ('min_child_weight', 3), ('n_estimators', 2159), ('subsample', 0.6813627724945288)])

# %%
joblib.dump(bayes_cv1.best_estimator_, 'xgb_model_p3_tau_no_aug.joblib')
# Out:
# ['xgb_model_p3_tau_no_aug.joblib']

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Evaluate the performance of the best model on the test set
y_pred3 = bayes_cv3.predict(X_test3)
mae = mean_absolute_error(y_test3, y_pred3)
rmse = mean_squared_error(y_test3, y_pred3, squared=False)
r2 = r2_score(y_test3, y_pred3)

print("Mean Absolute Error: {:.3f}".format(mae))
print("Root Mean Squared Error: {:.3f}".format(rmse))
print("R-squared Score: {:.3f}".format(r2))
# Out:
# Mean Absolute Error: 0.017
# Root Mean Squared Error: 0.030
# R-squared Score: 0.972
